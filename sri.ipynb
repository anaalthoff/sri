# %% [markdown]
# <a href="https://colab.research.google.com/github/anaalthoff/sri/blob/main/sri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tópicos Especiais em Computação: Semântica e Recuperação de Informação**

# %% [markdown]
# ## 1) Clonar o repositório do Github
#
# Primeiro, clonar o repositório https://github.com/osmarbraz/sri para ter acesso aos notebooks.

# %%
# Clone the GitHub repository
# !git clone https://github.com/osmarbraz/sri.git
# Out:
# Cloning into 'sri'...
# remote: Enumerating objects: 794, done.
# remote: Counting objects: 100% (272/272), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 794 (delta 225), reused 176 (delta 176), pack-reused 522 (from 3)
# Receiving objects: 100% (794/794), 64.82 MiB | 17.73 MiB/s, done.
# Resolving deltas: 100% (480/480), done.

# %% [markdown]
# ## 2) Mountar o Google Drive
#
# Depois, é necessário montar o Google Drive para ser capaz de salvar os arquivos lá.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3) Copiar arquivos .ipynb
#
# Copiar notebooks para poder executar os exercícios.

# %%
# Define the source and destination paths
source_dir = 'sri'
destination_dir = '/content/drive/My Drive/Colab Notebooks/SRI'

# Copy all .ipynb files from the cloned repository to the Google Drive folder
# !cp "{source_dir}"/*.ipynb "{destination_dir}"

print(f"Notebooks from '{source_dir}' copied to '{destination_dir}'")
# Out:
# Notebooks from 'sri' copied to '/content/drive/My Drive/Colab Notebooks/SRI'
